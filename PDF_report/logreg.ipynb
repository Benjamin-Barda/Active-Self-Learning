# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
first = pd.read_csv("run-Mar15_11-50-27_benjamin-tag-Loss_train.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Mar15_11-50-27_benjamin-tag-Loss_train_epoch.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Mar15_11-50-27_benjamin-tag-Misc_learning_rate.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Apr03_15-51-57_benjamin-tag-Train_Loss.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
plt.xticks(np.arange(0, 5000+1, 500))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Apr03_15-51-57_benjamin-tag-Eval_Acc.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
plt.xticks(np.arange(0, 5000+1, 500))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Apr03_15-51-57_benjamin-tag-Eval_Loss.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(7,4.7))
plt.xticks(np.arange(0, 5000+1, 500))
_ = plt.plot(first["Step"], first["Value"])

# %%
first = pd.read_csv("run-Apr03_15-51-57_benjamin-tag-Sample#_Epoch.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(8,6))
_ = plt.plot(first["Value"],first["Step"])
plt.yticks(np.arange(0, 5000+1, 500))
_ = plt.xticks(np.arange(2,22,2))

# %%
first = pd.read_csv("run-Apr03_15-51-57_benjamin-tag-LearningRate.csv", usecols=["Step","Value"])
fig = plt.figure(figsize=(15,4.7))
_ = plt.plot(first["Step"], first["Value"])
